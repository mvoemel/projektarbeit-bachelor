# %% [markdown]
# # Log Book
#
# Containing configs and results of train and tune runs.

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# TBA
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `7` (Baseline + Symmetric Cross-Attention + Transformer Block + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# TBA
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `6` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN))
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 32,
#     'learning_rate': 0.0009070418872442555,
#     'dropout_rate': 0.07029984566604908,
#     'l2_reg': 0.007058882123454644,
#     'ff_dim': 116,
#     'num_layers': 4,
#     'num_heads': 33,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `5` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 32,
#     'learning_rate': 0.0003132071576424828,
#     'dropout_rate': 0.00396683619911593,
#     'l2_reg': 1.8144367529691835e-05,
#     'ff_dim': 47,
#     'num_layers': 4,
#     'num_heads': 22,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `4` (Baseline + Symmetric Cross-Attention + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 128,
#     'learning_rate': 0.00853618986286683,
#     'dropout_rate': 0.40419867405823057,
#     'l2_reg': 8.200518402245828e-05,
#     'ff_dim': 34,
#     'num_layers': 4,
#     'num_heads': 23,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `3` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN))
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 16,
#     'learning_rate': 0.00010165521393155528,
#     'dropout_rate': 0.3575037388911965,
#     'l2_reg': 0.0016339476006754783,
#     'ff_dim': 200,
#     'num_layers': 4,
#     'num_heads': 39,
#     'activation': 'relu',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Test Results:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 64,
#     'learning_rate': 0.005181094478840494,
#     'dropout_rate': 0.2841676509302403,
#     'l2_reg': 0.0007739952170712114,
#     'ff_dim': 46,
#     'num_layers': 3,
#     'num_heads': 11,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.5747
# loss: 1.2618
# precision: 0.2680
# recall: 0.8960
# roc_auc: 0.7619
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 64,
#     'learning_rate': 0.008781408196485976,
#     'dropout_rate': 0.4812236474710556,
#     'l2_reg': 5.69307476764461e-05,
#     'ff_dim': 107,
#     'num_layers': 2,
#     'num_heads': 15,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.6508
# loss: 0.7888
# precision: 0.2675
# recall: 0.6302
# roc_auc: 0.7375
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 64,
#     'learning_rate': 0.0032911586783875425,
#     'dropout_rate': 0.16265300138726627,
#     'l2_reg': 0.009500132352791754,
#     'ff_dim': 89,
#     'num_layers': 3,
#     'num_heads': 40,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7260 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7529 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 3 | 0.7526 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7513 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7768 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.8130 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7805 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7761 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | 0.7565 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ |
# | 10 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 11 | 0.7737 | 64 | 0.001500 | 0.1535 | 0.000340 | 126 | 5 | 5 | leaky_relu | Periodic | ✓ |
# | 12 | **0.8619** ⭐ | 64 | 0.003291 | 0.1627 | 0.009500 | 89 | 3 | 40 | tanh | Periodic | ✓ Best |
# | 13 | 0.7769 | 16 | 0.002635 | 0.3336 | 0.009956 | 75 | 3 | 44 | tanh | Periodic | ✓ |
# | 14 | 0.7750 | 64 | 0.004570 | 0.2203 | 0.009729 | 39 | 2 | 41 | tanh | Periodic | ✓ |
# | 15 | 0.7573 | 64 | 0.000697 | 0.1440 | 0.001514 | 101 | 4 | 12 | tanh | Periodic | ✓ |
# | 16 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 17 | 0.7629 | 16 | 0.001035 | 0.3572 | 0.003586 | 57 | 3 | 40 | tanh | Periodic | ✓ |
# | 18 | 0.7300 | 128 | 0.002166 | 0.2051 | 0.000711 | 99 | 1 | 47 | tanh | Periodic | ✓ |
# | 19 | 0.7726 | 64 | 0.004459 | 0.2905 | 0.000120 | 91 | 3 | 20 | tanh | Periodic | ✓ |
# | 20 | 0.7537 | 64 | 0.000730 | 0.0820 | 0.000657 | 18 | 2 | 29 | leaky_relu | Periodic | ✓ |
# | 21 | 0.7788 | 64 | 0.000122 | 0.1534 | 4.41e-05 | 123 | 5 | 34 | relu | PLE | ✓ |
# | 22 | 0.7706 | 64 | 0.001488 | 0.1149 | 0.004161 | 198 | 4 | 36 | relu | PLE | ✓ |
# | 23 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 24 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 25 | 0.7725 | 64 | 0.000104 | 0.0196 | 0.000452 | 86 | 3 | 11 | relu | Periodic | ✓ |
# | 26 | 0.7673 | 128 | 0.001679 | 0.2631 | 0.001192 | 117 | 3 | 37 | tanh | PLE | ✓ |
# | 27 | 0.7393 | 32 | 0.000639 | 0.1814 | 2.28e-05 | 114 | 2 | 44 | tanh | Periodic | ✓ |
# | 28 | 0.7594 | 16 | 0.001030 | 0.1122 | 0.006049 | 58 | 4 | 20 | leaky_relu | PLE | ✓ |
# | 29 | 0.7668 | 32 | 0.006308 | 0.0938 | 5.63e-05 | 58 | 5 | 28 | relu | PLE | ✓ |
# | 30 | 0.7294 | 64 | 0.000446 | 0.2528 | 1.69e-05 | 88 | 1 | 37 | tanh | Periodic | ✓ |
# | 31 | 0.7942 | 64 | 0.000116 | 0.1453 | 4.19e-05 | 123 | 5 | 33 | relu | PLE | ✓ |
# | 32 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 33 | 0.7785 | 64 | 0.000152 | 0.1329 | 7.87e-05 | 161 | 4 | 24 | relu | PLE | ✓ |
# | 34 | 0.7415 | 64 | 0.000237 | 0.1889 | 1.61e-05 | 183 | 4 | 30 | relu | PLE | ✓ |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `7` (Baseline + Symmetric Cross-Attention + Transformer Block + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 128,
#     'learning_rate': 0.00014580160670561796,
#     'dropout_rate': 0.4981126922026228,
#     'l2_reg': 0.000453617845185874,
#     'ff_dim': 111,
#     'num_layers': 5,
#     'num_heads': 10,
#     'activation': 'relu',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7270 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7205 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | 0.7483 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 3 | 0.7901 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7713 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7402 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.7696 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 9 | 0.7516 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 10 | 0.7414 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 11 | 0.7735 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 12 | 0.7412 | 16 | 0.001256 | 0.4848 | 0.006815 | 136 | 5 | 39 | leaky_relu | Periodic | ✓ |
# | 13 | 0.7686 | 16 | 0.001119 | 0.3879 | 0.002482 | 25 | 5 | 12 | leaky_relu | Periodic | ✓ |
# | 14 | 0.7473 | 128 | 0.003007 | 0.4914 | 0.000116 | 128 | 5 | 31 | relu | Periodic | ✓ |
# | 15 | 0.7614 | 16 | 0.009244 | 0.2006 | 0.001535 | 44 | 3 | 44 | relu | Periodic | ✓ |
# | 16 | 0.7667 | 128 | 0.003332 | 0.3588 | 0.000132 | 198 | 4 | 30 | leaky_relu | Periodic | ✓ |
# | 17 | 0.7820 | 128 | 0.000111 | 0.4846 | 0.006572 | 117 | 3 | 17 | tanh | Periodic | ✓ |
# | 18 | 0.7800 | 16 | 0.000105 | 0.1548 | 0.008688 | 138 | 3 | 2 | relu | Periodic | ✓ |
# | 19 | 0.7626 | 16 | 0.000101 | 0.0118 | 0.003327 | 109 | 3 | 16 | relu | Periodic | ✓ |
# | 20 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 21 | 0.7454 | 16 | 0.000721 | 0.3512 | 0.004275 | 195 | 3 | 30 | leaky_relu | Periodic | ✓ |
# | 22 | **0.8214** ⭐ | 128 | 0.000146 | 0.4981 | 0.000454 | 111 | 5 | 10 | relu | Periodic | ✓ Best |
# | 23 | 0.7748 | 128 | 0.000153 | 0.4596 | 0.000358 | 112 | 5 | 9 | relu | Periodic | ✓ |
# | 24 | 0.7834 | 128 | 0.000252 | 0.4998 | 0.001837 | 92 | 5 | 19 | relu | Periodic | ✓ |
# | 25 | 0.7871 | 128 | 0.000228 | 0.4397 | 0.000766 | 91 | 5 | 2 | relu | Periodic | ✓ |
# | 26 | 0.7898 | 128 | 0.000280 | 0.4365 | 0.000695 | 61 | 5 | 2 | relu | Periodic | ✓ |
# | 27 | 0.7857 | 128 | 0.000706 | 0.3631 | 0.000215 | 51 | 5 | 6 | relu | Periodic | ✓ |
# | 28 | 0.7531 | 16 | 0.000286 | 0.4239 | 0.000613 | 57 | 4 | 11 | relu | Periodic | ✓ |
# | 29 | 0.7954 | 32 | 0.000149 | 0.4565 | 0.001211 | 16 | 5 | 5 | relu | Periodic | ✓ |
# | 30 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 31 | 0.7628 | 32 | 0.000144 | 0.4639 | 0.000248 | 185 | 4 | 34 | relu | Periodic | ✓ |
# | 32 | 0.7591 | 32 | 0.000550 | 0.3906 | 0.004122 | 17 | 5 | 5 | relu | Periodic | ✓ |
# | 33 | 0.8109 | 32 | 0.000304 | 0.4370 | 0.001150 | 81 | 5 | 4 | relu | Periodic | ✓ |
# | 34 | 0.8147 | 32 | 0.000186 | 0.4659 | 0.001179 | 80 | 5 | 9 | relu | Periodic | ✓ |
# | 35 | 0.7746 | 32 | 0.000125 | 0.3990 | 0.001138 | 80 | 5 | 8 | relu | Periodic | ✓ |
# | 36 | 0.7617 | 32 | 0.000187 | 0.3136 | 0.000523 | 103 | 4 | 5 | relu | Periodic | ✓ |
# | 37 | 0.8084 | 32 | 0.000353 | 0.4618 | 0.000450 | 122 | 5 | 10 | relu | Periodic | ✓ |
# | 38 | 0.7864 | 32 | 0.000368 | 0.4084 | 0.000182 | 82 | 5 | 10 | relu | PLE | ✓ |
# | 39 | 0.7190 | 32 | 0.001645 | 0.4991 | 0.000394 | 122 | 4 | 20 | relu | Periodic | ✓ |
# | 40 | 0.7623 | 32 | 0.000439 | 0.2457 | 0.000460 | 99 | 5 | 14 | leaky_relu | PLE | ✓ |
# | 41 | 0.8034 | 64 | 0.000310 | 0.3753 | 0.000849 | 67 | 4 | 8 | relu | Periodic | ✓ |
# | 42 | 0.7763 | 32 | 0.000203 | 0.4211 | 5.65e-05 | 85 | 5 | 14 | relu | PLE | ✓ |
# | 43 | 0.8014 | 64 | 0.000307 | 0.4658 | 0.000914 | 67 | 4 | 9 | relu | Periodic | ✓ |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `6` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN))
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 32,
#     'learning_rate': 0.0009070418872442555,
#     'dropout_rate': 0.07029984566604908,
#     'l2_reg': 0.007058882123454644,
#     'ff_dim': 116,
#     'num_layers': 4,
#     'num_heads': 33,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7593 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 2 | 0.7644 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 3 | 0.7913 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7342 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 6 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 7 | 0.7743 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7454 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 10 | 0.8063 | 16 | 0.000981 | 0.0038 | 0.006815 | 142 | 5 | 48 | leaky_relu | Periodic | ✓ |
# | 11 | 0.7858 | 16 | 0.001096 | 0.0086 | 0.008154 | 140 | 5 | 48 | leaky_relu | Periodic | ✓ |
# | 12 | 0.7955 | 16 | 0.001087 | 0.3575 | 0.002089 | 138 | 4 | 40 | leaky_relu | Periodic | ✓ |
# | 13 | 0.8040 | 16 | 0.001068 | 0.3347 | 0.009956 | 137 | 4 | 41 | leaky_relu | Periodic | ✓ |
# | 14 | 0.7686 | 16 | 0.002237 | 0.1759 | 0.009729 | 138 | 3 | 43 | leaky_relu | Periodic | ✓ |
# | 15 | 0.7549 | 16 | 0.002106 | 0.0016 | 0.004884 | 125 | 4 | 43 | leaky_relu | Periodic | ✓ |
# | 16 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 17 | 0.7883 | 16 | 0.000745 | 0.3219 | 0.000244 | 115 | 5 | 46 | leaky_relu | Periodic | ✓ |
# | 18 | 0.7724 | 16 | 0.002166 | 0.3668 | 0.004259 | 37 | 4 | 50 | leaky_relu | Periodic | ✓ |
# | 19 | 0.7854 | 16 | 0.004459 | 0.1110 | 0.001067 | 90 | 3 | 43 | leaky_relu | Periodic | ✓ |
# | 20 | 0.7444 | 128 | 0.000593 | 0.2140 | 0.000202 | 200 | 5 | 31 | leaky_relu | Periodic | ✓ |
# | 21 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 22 | 0.7171 | 16 | 0.001213 | 0.3922 | 0.005220 | 126 | 4 | 40 | leaky_relu | Periodic | ✓ |
# | 23 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 24 | 0.7634 | 16 | 0.000813 | 0.4221 | 0.001589 | 127 | 5 | 35 | leaky_relu | Periodic | ✓ |
# | 25 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 26 | 0.7820 | 16 | 0.000435 | 0.3483 | 0.006061 | 112 | 5 | 42 | leaky_relu | Periodic | ✓ |
# | 27 | 0.7615 | 16 | 0.001590 | 0.2244 | 0.000514 | 17 | 4 | 47 | leaky_relu | Periodic | ✓ |
# | 28 | 0.7332 | 128 | 0.000532 | 0.4348 | 0.001304 | 169 | 3 | 38 | leaky_relu | Periodic | ✓ |
# | 29 | 0.7756 | 32 | 0.002982 | 0.1701 | 0.003296 | 135 | 4 | 29 | leaky_relu | PLE | ✓ |
# | 30 | 0.7926 | 32 | 0.000868 | 0.0429 | 0.007187 | 95 | 4 | 35 | tanh | Periodic | ✓ |
# | 31 | 0.7617 | 32 | 0.000865 | 0.0496 | 0.006685 | 98 | 4 | 35 | tanh | Periodic | ✓ |
# | 32 | 0.7561 | 32 | 0.001432 | 0.0432 | 0.005051 | 73 | 3 | 40 | tanh | Periodic | ✓ |
# | 33 | 0.7717 | 32 | 0.000476 | 0.0251 | 0.002210 | 51 | 2 | 21 | tanh | Periodic | ✓ |
# | 34 | **0.8218** ⭐ | 32 | 0.000907 | 0.0703 | 0.007059 | 116 | 4 | 33 | tanh | PLE | ✓ Best |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `5` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 32,
#     'learning_rate': 0.0003132071576424828,
#     'dropout_rate': 0.00396683619911593,
#     'l2_reg': 1.8144367529691835e-05,
#     'ff_dim': 47,
#     'num_layers': 4,
#     'num_heads': 22,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.8028 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7391 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 3 | 0.7820 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7725 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7334 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.7781 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7477 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7317 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | 0.7800 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ |
# | 10 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 11 | 0.7594 | 16 | 0.000714 | 0.0564 | 0.006801 | 199 | 5 | 36 | leaky_relu | Periodic | ✓ |
# | 12 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 13 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 14 | 0.7951 | 128 | 0.000235 | 0.1628 | 0.009729 | 200 | 3 | 42 | leaky_relu | PLE | ✓ |
# | 15 | 0.7817 | 128 | 0.000458 | 0.1383 | 0.006497 | 129 | 3 | 43 | leaky_relu | PLE | ✓ |
# | 16 | 0.7901 | 128 | 0.001901 | 0.0571 | 0.000220 | 164 | 3 | 50 | leaky_relu | PLE | ✓ |
# | 17 | 0.7538 | 32 | 0.000584 | 0.1645 | 0.000497 | 167 | 3 | 42 | leaky_relu | PLE | ✓ |
# | 18 | 0.7797 | 128 | 0.000198 | 0.0870 | 1.00e-05 | 125 | 2 | 39 | leaky_relu | PLE | ✓ |
# | 19 | 0.7786 | 128 | 0.000106 | 0.2005 | 0.000144 | 26 | 4 | 46 | tanh | PLE | ✓ |
# | 20 | 0.7448 | 32 | 0.001308 | 0.0966 | 0.003282 | 200 | 4 | 36 | leaky_relu | PLE | ✓ |
# | 21 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 22 | 0.7849 | 128 | 0.001515 | 0.0530 | 0.001304 | 186 | 3 | 48 | leaky_relu | PLE | ✓ |
# | 23 | 0.7765 | 128 | 0.003120 | 0.0818 | 0.009951 | 176 | 3 | 39 | leaky_relu | PLE | ✓ |
# | 24 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 25 | 0.7624 | 32 | 0.000969 | 0.1132 | 8.83e-05 | 178 | 3 | 2 | tanh | PLE | ✓ |
# | 26 | 0.7945 | 128 | 0.000555 | 0.0397 | 0.000283 | 128 | 4 | 47 | leaky_relu | PLE | ✓ |
# | 27 | 0.7951 | 128 | 0.000285 | 0.0276 | 4.47e-05 | 113 | 4 | 34 | tanh | PLE | ✓ |
# | 28 | 0.8021 | 32 | 0.000262 | 0.0006 | 1.60e-05 | 46 | 4 | 27 | tanh | PLE | ✓ |
# | 29 | 0.7760 | 32 | 0.000144 | 0.3206 | 1.93e-05 | 63 | 4 | 26 | tanh | PLE | ✓ |
# | 30 | 0.7928 | 32 | 0.000368 | 0.2086 | 1.32e-05 | 52 | 5 | 19 | tanh | PLE | ✓ |
# | 31 | 0.8118 | 32 | 0.000289 | 0.0127 | 4.19e-05 | 91 | 4 | 29 | tanh | PLE | ✓ |
# | 32 | 0.8169 | 32 | 0.000247 | 0.0048 | 1.89e-05 | 44 | 4 | 23 | tanh | PLE | ✓ |
# | 33 | **0.8171** ⭐ | 32 | 0.000313 | 0.0040 | 1.81e-05 | 47 | 4 | 22 | tanh | PLE | ✓ Best |
# | 34 | 0.8168 | 32 | 0.000374 | 0.0741 | 3.76e-05 | 82 | 4 | 22 | tanh | PLE | ✓ |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `4` (Baseline + Symmetric Cross-Attention + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 128,
#     'learning_rate': 0.00853618986286683,
#     'dropout_rate': 0.40419867405823057,
#     'l2_reg': 8.200518402245828e-05,
#     'ff_dim': 34,
#     'num_layers': 4,
#     'num_heads': 23,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7759 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7684 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | **0.8278** ⭐ | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ Best |
# | 3 | 0.7853 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7546 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7464 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.7726 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7827 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7357 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | 0.7725 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ |
# | 10 | 0.8011 | 128 | 0.001311 | 0.3489 | 0.000110 | 18 | 4 | 2 | leaky_relu | PLE | ✓ |
# | 11 | 0.7929 | 128 | 0.001627 | 0.3726 | 0.000132 | 21 | 4 | 2 | leaky_relu | PLE | ✓ |
# | 12 | 0.7861 | 128 | 0.001087 | 0.3566 | 0.000121 | 19 | 4 | 44 | leaky_relu | PLE | ✓ |
# | 13 | 0.7594 | 128 | 0.009272 | 0.3709 | 0.009956 | 47 | 3 | 13 | leaky_relu | PLE | ✓ |
# | 14 | 0.7198 | 128 | 0.003332 | 0.4172 | 0.000131 | 132 | 3 | 21 | leaky_relu | PLE | ✓ |
# | 15 | 0.7579 | 128 | 0.003743 | 0.3114 | 0.000306 | 45 | 3 | 9 | tanh | PLE | ✓ |
# | 16 | 0.7674 | 16 | 0.000682 | 0.0155 | 8.49e-05 | 43 | 4 | 2 | leaky_relu | PLE | ✓ |
# | 17 | 0.7880 | 128 | 0.001911 | 0.1857 | 0.000323 | 134 | 5 | 41 | leaky_relu | PLE | ✓ |
# | 18 | 0.7574 | 128 | 0.000660 | 0.4286 | 1.01e-05 | 67 | 4 | 21 | tanh | Periodic | ✓ |
# | 19 | 0.7705 | 128 | 0.006260 | 0.3317 | 5.27e-05 | 31 | 2 | 9 | leaky_relu | PLE | ✓ |
# | 20 | 0.7561 | 16 | 0.002066 | 0.3981 | 0.000657 | 57 | 5 | 38 | tanh | PLE | ✓ |
# | 21 | 0.8112 | 128 | 0.001364 | 0.3745 | 0.000191 | 16 | 4 | 2 | leaky_relu | PLE | ✓ |
# | 22 | 0.7804 | 128 | 0.000897 | 0.4588 | 0.000223 | 31 | 4 | 4 | leaky_relu | PLE | ✓ |
# | 23 | 0.7740 | 128 | 0.001394 | 0.2695 | 6.68e-05 | 16 | 3 | 7 | leaky_relu | PLE | ✓ |
# | 24 | 0.7832 | 128 | 0.005101 | 0.3414 | 0.000728 | 38 | 4 | 13 | leaky_relu | PLE | ✓ |
# | 25 | 0.7835 | 128 | 0.000104 | 0.3907 | 0.000160 | 59 | 3 | 17 | leaky_relu | PLE | ✓ |
# | 26 | 0.7866 | 128 | 0.000520 | 0.4431 | 4.89e-05 | 88 | 5 | 10 | tanh | Periodic | ✓ |
# | 27 | 0.7653 | 128 | 0.002546 | 0.3177 | 0.000448 | 26 | 4 | 5 | leaky_relu | PLE | ✓ |
# | 28 | 0.7910 | 32 | 0.001081 | 0.2970 | 0.000205 | 55 | 4 | 28 | leaky_relu | PLE | ✓ |
# | 29 | 0.7861 | 16 | 0.005045 | 0.0938 | 0.001286 | 131 | 4 | 20 | tanh | PLE | ✓ |
# | 30 | 0.7574 | 32 | 0.002718 | 0.3947 | 1.87e-05 | 34 | 5 | 11 | tanh | PLE | ✓ |
# | 31 | 0.8018 | 128 | 0.001563 | 0.3576 | 9.80e-05 | 20 | 4 | 2 | leaky_relu | PLE | ✓ |
# | 32 | 0.7629 | 128 | 0.001352 | 0.3498 | 9.48e-05 | 16 | 4 | 5 | leaky_relu | PLE | ✓ |
# | 33 | 0.7381 | 128 | 0.000596 | 0.4637 | 3.53e-05 | 30 | 3 | 2 | leaky_relu | PLE | ✓ |
# | 34 | 0.7715 | 128 | 0.000898 | 0.2801 | 0.000208 | 44 | 5 | 6 | relu | PLE | ✓ |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `3` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN))
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 16,
#     'learning_rate': 0.00010165521393155528,
#     'dropout_rate': 0.3575037388911965,
#     'l2_reg': 0.0016339476006754783,
#     'ff_dim': 200,
#     'num_layers': 4,
#     'num_heads': 39,
#     'activation': 'relu',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7672 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 2 | 0.7412 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 3 | 0.8206 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7772 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 6 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 7 | 0.7917 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7691 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 10 | 0.7731 | 16 | 0.000981 | 0.0038 | 0.006815 | 142 | 5 | 48 | leaky_relu | Periodic | ✓ |
# | 11 | 0.7976 | 16 | 0.000105 | 0.1355 | 0.001217 | 200 | 5 | 35 | relu | Periodic | ✓ |
# | 12 | **0.8488** ⭐ | 16 | 0.000102 | 0.3575 | 0.001634 | 200 | 4 | 39 | relu | Periodic | ✓ Best |
# | 13 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 14 | 0.7566 | 16 | 0.000561 | 0.4923 | 0.001976 | 135 | 3 | 41 | relu | Periodic | ✓ |
# | 15 | 0.8250 | 16 | 0.000111 | 0.3415 | 0.000177 | 196 | 4 | 30 | relu | Periodic | ✓ |
# | 16 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 17 | 0.7597 | 16 | 0.000745 | 0.3897 | 0.000375 | 127 | 4 | 17 | relu | Periodic | ✓ |
# | 18 | 0.7707 | 16 | 0.002166 | 0.3250 | 0.000199 | 30 | 3 | 29 | relu | Periodic | ✓ |
# | 19 | 0.7759 | 16 | 0.001515 | 0.2005 | 0.000631 | 197 | 3 | 39 | relu | Periodic | ✓ |
# | 20 | 0.7961 | 128 | 0.000516 | 0.4330 | 0.000138 | 164 | 4 | 46 | leaky_relu | Periodic | ✓ |
# | 21 | 0.8296 | 16 | 0.000212 | 0.4385 | 0.003779 | 180 | 5 | 31 | relu | Periodic | ✓ |
# | 22 | 0.7803 | 16 | 0.000146 | 0.3660 | 0.005243 | 184 | 5 | 21 | relu | Periodic | ✓ |
# | 23 | 0.7863 | 16 | 0.000113 | 0.4389 | 0.003977 | 199 | 4 | 37 | relu | Periodic | ✓ |
# | 24 | 0.7782 | 16 | 0.000243 | 0.2834 | 0.001142 | 17

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 64,
#     'learning_rate': 0.005181094478840494,
#     'dropout_rate': 0.2841676509302403,
#     'l2_reg': 0.0007739952170712114,
#     'ff_dim': 46,
#     'num_layers': 3,
#     'num_heads': 11,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7803 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7641 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | 0.8000 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 3 | 0.7728 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7499 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7868 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.8059 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7508 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7609 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | 0.7967 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ |
# | 10 | 0.7782 | 128 | 0.002510 | 0.0038 | 0.000198 | 134 | 3 | 2 | leaky_relu | Periodic | ✓ |
# | 11 | 0.7860 | 128 | 0.009562 | 0.3566 | 0.000173 | 25 | 4 | 2 | tanh | Periodic | ✓ |
# | 12 | 0.7968 | 128 | 0.003099 | 0.3648 | 0.000383 | 31 | 3 | 17 | tanh | Periodic | ✓ |
# | 13 | 0.7944 | 16 | 0.003951 | 0.1905 | 0.009956 | 64 | 4 | 8 | leaky_relu | PLE | ✓ |
# | 14 | 0.7401 | 128 | 0.001221 | 0.3657 | 8.52e-05 | 111 | 2 | 43 | tanh | PLE | ✓ |
# | 15 | **0.8623** ⭐ | 64 | 0.005181 | 0.2842 | 0.000774 | 46 | 3 | 11 | tanh | Periodic | ✓ Best |
# | 16 | 0.7266 | 64 | 0.001432 | 0.2921 | 0.000813 | 56 | 2 | 10 | leaky_relu | Periodic | ✓ |
# | 17 | 0.7892 | 64 | 0.004778 | 0.1317 | 0.001766 | 97 | 3 | 10 | tanh | Periodic | ✓ |
# | 18 | 0.7791 | 64 | 0.000733 | 0.2335 | 0.000617 | 136 | 1 | 7 | tanh | Periodic | ✓ |
# | 19 | 0.8205 | 64 | 0.001942 | 0.1711 | 0.007967 | 48 | 3 | 15 | tanh | Periodic | ✓ |
# | 20 | 0.7945 | 16 | 0.002023 | 0.1561 | 0.006485 | 42 | 3 | 19 | leaky_relu | Periodic | ✓ |
# | 21 | 0.8434 | 64 | 0.005587

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 64,
#     'learning_rate': 0.008781408196485976,
#     'dropout_rate': 0.4812236474710556,
#     'l2_reg': 5.69307476764461e-05,
#     'ff_dim': 107,
#     'num_layers': 2,
#     'num_heads': 15,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7909 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7654 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | 0.7495 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE | ✓ |
# | 3 | 0.7565 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.7722 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.7477 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.8100 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7720 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7857 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | **0.8445** ⭐ | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ Best |
# | 10 | 0.7400 | 128 | 0.001311 | 0.0038 | 0.000121 | 134 | 3 | 2 | leaky_relu | Periodic | ✓ |
# | 11 | 0.8132 | 64 | 0.008611 | 0.3486 | 0.000340 | 109 | 2 | 7 | tanh | Periodic | ✓ |
# | 12 | 0.8280 | 64 | 0.008738 | 0.3543 | 0.000130 | 128 | 2 | 12 | tanh | Periodic | ✓ |
# | 13 | 0.7799 | 16 | 0.003024 | 0.4976 | 9.44e-05 | 137 | 2 | 14 | leaky_relu | Periodic | ✓ |
# | 14 | 0.7742 | 64 | 0.003874 | 0.3782 | 0.009729 | 132 | 3 | 16 | tanh | Periodic | ✓ |
# | 15 | 0.8089 | 64 | 0.001443 | 0.3296 | 0.000146 | 43 | 2 | 10 | tanh | Periodic | ✓ |
# | 16 | 0.7566 | 64 | 0.005312 | 0.4361 | 6.59e-05 | 109 | 3 | 18 | leaky_relu | Periodic | ✓ |
# | 17 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 18 | 0.8219 | 128 | 0.002166 | 0.3798 | 1.00e-05 | 61 | 4 | 2 | tanh | Periodic | ✓ |
# | 19 | 0.7745 | 64 | 0.005852 | 0.2005 | 0.000198 | 91 | 2 | 12 | tanh | Periodic | ✓ |
# | 20 | 0.7546 | 64 | 0.009835 | 0.2990 | 6.17e-05 | 18 | 3 | 21 | leaky_relu | Periodic | ✓ |
# | 21 | 0.8166 | 128 | 0.002340 | 0.3782 | 1.32e-05 | 63 | 4 | 2 | tanh | Periodic | ✓ |
# | 22 | 0.8113 | 128 | 0.002193 | 0.4371 | 3.59e-05 | 123 | 4 | 7 | tanh | Periodic | ✓ |
# | 23 | 0.7943 | 128 | 0.000709 | 0.3715 | 1.13e-05 | 50 | 3 | 10 | tanh | Periodic | ✓ |
# | 24 | 0.7626 | 128 | 0.005754 | 0.4144 | 4.92e-05 | 90 | 5 | 5 | tanh | Periodic | ✓ |
# | 25 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 26 | 0.7941 | 16 | 0.004821 | 0.3406 | 0.000202 | 121 | 4 | 19 | tanh | Periodic | ✓ |
# | 27 | 0.7607 | 32 | 0.002071 | 0.3987 | 0.000669 | 83 | 2 | 4 | tanh | Periodic | ✓ |
# | 28 | 0.7402 | 64 | 0.000971 | 0.3000 | 0.000206 | 58 | 1 | 14 | leaky_relu | Periodic | ✓ |
# | 29 | 0.8227 | 32 | 0.006489 | 0.1589 | 1.65e-05 | 98 | 4 | 29 | tanh | PLE | ✓ |
# | 30 | 0.8200 | 32 | 0.007260 | 0.1418 | 4.65e-05 | 99 | 3 | 39 | tanh | PLE | ✓ |
# | 31 | 0.7700 | 32 | 0.006972 | 0.1510 | 1.89e-05 | 111 | 4 | 29 | tanh | PLE | ✓ |
# | 32 | 0.8014 | 32 | 0.004045 | 0.0829 | 1.18e-05 | 74 | 4 | 25 | tanh | PLE | ✓ |
# | 33 | 0.8434 | 32 | 0.009712 | 0.1941 | 2.00e-05 | 121 | 4 | 34 | tanh | PLE | ✓ |
# | 34 | 0.6789 | 32 | 0.009693 | 0.1854 | 2.15e-05 | 120 | 5 | 36 | tanh | PLE | ✓ |

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 128,
#     'learning_rate': 0.0018403904521258978,
#     'dropout_rate': 0.13841159467909692,
#     'l2_reg': 0.00022266266296386451,
#     'ff_dim': 64,
#     'num_layers': 3,
#     'num_heads': 21,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.7239
# loss: 0.6128
# precision: 0.3396
# recall: 0.6949
# roc_auc: 0.7988
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `7` (Baseline + Symmetric Cross-Attention + Transformer Block + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 128,
#     'learning_rate': 0.009272361819517416,
#     'dropout_rate': 0.3709338442703634,
#     'l2_reg': 0.009956055660659066,
#     'ff_dim': 47,
#     'num_layers': 3,
#     'num_heads': 13,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8150
# loss: 2.7813
# precision: 0.4568
# recall: 0.5820
# roc_auc: 0.8231
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `6` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN))
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 16,
#     'learning_rate': 0.0019879809384288102,
#     'dropout_rate': 0.3316929188322714,
#     'l2_reg': 0.009956055660659066,
#     'ff_dim': 141,
#     'num_layers': 2,
#     'num_heads': 41,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.6527
# loss: 2.9638
# precision: 0.2951
# recall: 0.7807
# roc_auc: 0.7889
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `5` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 64,
#     'learning_rate': 0.005285426279175433,
#     'dropout_rate': 0.46594630836578194,
#     'l2_reg': 4.047725053283987e-05,
#     'ff_dim': 123,
#     'num_layers': 2,
#     'num_heads': 12,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.6942
# loss: 0.5769
# precision: 0.2913
# recall: 0.5825
# roc_auc: 0.7286
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `4` (Baseline + Symmetric Cross-Attention + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 16,
#     'learning_rate': 0.006393277610030755,
#     'dropout_rate': 0.3565391348813297,
#     'l2_reg': 0.0003510299681926548,
#     'ff_dim': 156,
#     'num_layers': 2,
#     'num_heads': 30,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.7336
# loss: 0.8247
# precision: 0.3557
# recall: 0.7376
# roc_auc: 0.8374
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `3` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN))
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 64,
#     'learning_rate': 0.0012755680432249667,
#     'dropout_rate': 0.11792747175814695,
#     'l2_reg': 0.0005915217137821515,
#     'ff_dim': 59,
#     'num_layers': 4,
#     'num_heads': 4,
#     'activation': 'relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.6660
# loss: 0.7669
# precision: 0.2882
# recall: 0.6830
# roc_auc: 0.7461
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 32,
#     'learning_rate': 0.0059030125874360165,
#     'dropout_rate': 0.10530297634027552,
#     'l2_reg': 0.0020410048624941615,
#     'ff_dim': 76,
#     'num_layers': 3,
#     'num_heads': 42,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.7529
# loss: 0.9094
# precision: 0.3880
# recall: 0.8360
# roc_auc: 0.8684
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     'batch_size': 16,
#     'learning_rate': 0.005674018095876286,
#     'dropout_rate': 0.357649350688716,
#     'l2_reg': 0.00018082955891304315,
#     'ff_dim': 87,
#     'num_layers': 2,
#     'num_heads': 38,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8675
# loss: 0.3885
# precision: 0.5796
# recall: 0.7454
# roc_auc: 0.8855
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 128,
#     'learning_rate': 0.0018403904521258978,
#     'dropout_rate': 0.13841159467909692,
#     'l2_reg': 0.00022266266296386451,
#     'ff_dim': 64,
#     'num_layers': 3,
#     'num_heads': 21,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.8283 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.8118 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | **0.8346** | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.8209 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | 0.8039 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.8145 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.8116 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.8228 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7772 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.8189 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | 0.7993 | 128 | 0.001311 | 0.3489 | 0.000110 | 18 | 4 | 2 | leaky_relu | PLE |
# | 11 | 0.7704 | 128 | 0.001190 | 0.0046 | 1.11e-05 | 25 | 4 | 40 | tanh | PLE |
# | 12 | 0.8037 | 32 | 0.007904 | 0.0487 | 0.000109 | 136 | 4 | 39 | tanh | PLE |
# | 13 | **0.8413** | 128 | 0.000625 | 0.1241 | 0.009956 | 50 | 3 | 19 | leaky_relu | PLE |
# | 14 | 0.8122 | 128 | 0.003332 | 0.3657 | 0.009728 | 49 | 3 | 19 | leaky_relu | PLE |
# | 15 | 0.8035 | 128 | 0.000710 | 0.1694 | 0.000306 | 45 | 3 | 9 | leaky_relu | PLE |
# | 16 | **0.8442** | 128 | 0.000682 | 0.1225 | 0.008688 | 47 | 3 | 24 | leaky_relu | PLE |
# | 17 | 0.8099 | 16 | 0.000745 | 0.1147 | 0.008800 | 62 | 2 | 12 | leaky_relu | PLE |
# | 18 | 0.7904 | 128 | 0.002166 | 0.1888 | 0.003008 | 127 | 3 | 20 | leaky_relu | Periodic |
# | 19 | 0.8032 | 128 | 0.000574 | 0.1007 | 0.005310 | 90 | 2 | 28 | leaky_relu | PLE |
# | 20 | 0.7780 | 128 | 0.000104 | 0.0231 | 0.001205 | 47 | 3 | 48 | leaky_relu | PLE |
# | 21 | 0.8372 | 128 | 0.001533 | 0.3965 | 0.000191 | 34 | 4 | 23 | leaky_relu | PLE |
# | 22 | **0.8467** ⭐ | 128 | 0.001840 | 0.1384 | 0.000223 | 64 | 3 | 21 | leaky_relu | PLE |
# | 23 | 0.8068 | 128 | 0.002187 | 0.1368 | 0.000696 | 57 | 3 | 14 | leaky_relu | PLE |
# | 24 | 0.7987 | 16 | 0.000524 | 0.0669 | 0.004602 | 78 | 3 | 19 | leaky_relu | PLE |
# | 25 | 0.7942 | 128 | 0.000940 | 0.2045 | 0.001624 | 89 | 2 | 29 | leaky_relu | PLE |
# | 26 | 0.8059 | 128 | 0.002119 | 0.1574 | 0.005749 | 66 | 3 | 9 | leaky_relu | Periodic |
# | 27 | 0.8290 | 128 | 0.000446 | 0.1115 | 0.000714 | 31 | 2 | 22 | leaky_relu | PLE |
# | 28 | 0.8032 | 128 | 0.004604 | 0.2454 | 0.000318 | 126 | 3 | 26 | leaky_relu | PLE |
# | 29 | 0.8023 | 16 | 0.000840 | 0.0938 | 0.000191 | 52 | 4 | 35 | leaky_relu | PLE |
# | 30 | 0.7869 | 32 | 0.001600 | 0.0519 | 0.001213 | 16 | 3 | 15 | leaky_relu | PLE |
# | 31 | 0.8147 | 128 | 0.001655 | 0.2938 | 0.000186 | 37 | 5 | 24 | leaky_relu | PLE |
# | 32 | 0.7810 | 128 | 0.001212 | 0.2224 | 0.000196 | 35 | 4 | 21 | leaky_relu | PLE |
# | 33 | 0.8277 | 128 | 0.003238 | 0.3353 | 6.11e-05 | 73 | 4 | 24 | leaky_relu | PLE |
# | 34 | 0.8238 | 128 | 0.000583 | 0.1759 | 0.000465 | 39 | 3 | 31 | leaky_relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `7` (Baseline + Symmetric Cross-Attention + Transformer Block + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 128,
#     'learning_rate': 0.009272361819517416,
#     'dropout_rate': 0.3709338442703634,
#     'l2_reg': 0.009956055660659066,
#     'ff_dim': 47,
#     'num_layers': 3,
#     'num_heads': 13,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 0 | 0.8139 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.8041 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | **0.8169** | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7685 | 16 | 0.000234 | 0.4848 | 2.12e-03 | 189 | 5 | 31 | relu | Periodic |
# | 4 | 0.7958 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.7813 | 32 | 0.000171 | 0.4316 | 7.41e-04 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.8103 | 64 | 0.003483 | 0.2469 | 3.70e-04 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7828 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7367 | 32 | 0.000286 | 0.2136 | 2.84e-03 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.7432 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | **0.8274** | 128 | 0.001311 | 0.3489 | 1.10e-04 | 18 | 4 | 2 | leaky_relu | PLE |
# | 11 | 0.7737 | 128 | 0.001627 | 0.3726 | 1.32e-04 | 21 | 4 | 2 | leaky_relu | PLE |
# | 12 | 0.7584 | 128 | 0.001087 | 0.3566 | 1.21e-04 | 19 | 4 | 44 | leaky_relu | PLE |
# | 13 | **0.8366** ⭐ | 128 | 0.009272 | 0.3709 | 9.96e-03 | 47 | 3 | 13 | leaky_relu | PLE |
# | 14 | 0.8240 | 128 | 0.003274 | 0.3440 | 9.73e-03 | 51 | 3 | 10 | leaky_relu | PLE |
# | 15 | 0.8206 | 128 | 0.003743 | 0.1524 | 3.90e-04 | 140 | 3 | 5 | leaky_relu | PLE |
# | 16 | 0.8229 | 16 | 0.000682 | 0.0224 | 8.69e-03 | 47 | 3 | 15 | leaky_relu | PLE |
# | 17 | 0.8059 | 128 | 0.001652 | 0.3127 | 1.15e-03 | 131 | 2 | 10 | leaky_relu | PLE |
# | 18 | 0.7690 | 128 | 0.006047 | 0.4183 | 1.99e-04 | 61 | 5 | 2 | leaky_relu | Periodic |
# | 19 | 0.7617 | 128 | 0.000721 | 0.2005 | 3.76e-03 | 91 | 4 | 18 | leaky_relu | PLE |
# | 20 | 0.8293 | 16 | 0.000104 | 0.3027 | 7.18e-04 | 35 | 3 | 10 | leaky_relu | PLE |
# | 21 | 0.8062 | 16 | 0.001970 | 0.2985 | 7.80e-04 | 38 | 3 | 10 | leaky_relu | PLE |
# | 22 | 0.8039 | 16 | 0.000121 | 0.3678 | 2.33e-04 | 18 | 2 | 7 | leaky_relu | PLE |
# | 23 | 0.8155 | 16 | 0.000542 | 0.4454 | 5.15e-03 | 34 | 3 | 13 | leaky_relu | PLE |
# | 24 | 0.8106 | 16 | 0.000103 | 0.2546 | 1.26e-03 | 56 | 4 | 21 | leaky_relu | PLE |
# | 25 | 0.8122 | 128 | 0.002402 | 0.3270 | 5.18e-05 | 75 | 3 | 5 | leaky_relu | PLE |
# | 26 | 0.7720 | 128 | 0.001160 | 0.3918 | 6.15e-04 | 34 | 3 | 12 | leaky_relu | Periodic |
# | 27 | 0.8155 | 16 | 0.004262 | 0.2746 | 1.69e-03 | 44 | 2 | 19 | leaky_relu | PLE |
# | 28 | 0.7769 | 32 | 0.000518 | 0.2072 | 5.74e-03 | 64 | 4 | 6 | leaky_relu | PLE |
# | 29 | 0.8015 | 32 | 0.005646 | 0.3332 | 1.52e-04 | 28 | 4 | 39 | leaky_relu | PLE |
# | 30 | 0.8063 | 128 | 0.002566 | 0.4465 | 4.64e-04 | 91 | 5 | 2 | tanh | PLE |
# | 31 | 0.8170 | 128 | 0.005992 | 0.3455 | 7.57e-03 | 51 | 3 | 9 | leaky_relu | PLE |
# | 32 | 0.8132 | 128 | 0.002842 | 0.2968 | 1.51e-05 | 50 | 3 | 12 | leaky_relu | PLE |
# | 33 | 0.8209 | 128 | 0.004917 | 0.3836 | 3.71e-03 | 70 | 2 | 15 | leaky_relu | PLE |
# | 34 | 0.8185 | 128 | 0.009693 | 0.3278 | 9.10e-03 | 24 | 3 | 26 | leaky_relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `6` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN))
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 16,
#     'learning_rate': 0.0019879809384288102,
#     'dropout_rate': 0.3316929188322714,
#     'l2_reg': 0.009956055660659066,
#     'ff_dim': 141,
#     'num_layers': 2,
#     'num_heads': 41,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.8274 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.8248 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | 0.8073 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7900 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | **0.8398** | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.8096 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.8096 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7698 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7847 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.8176 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | 0.8150 | 128 | 0.000884 | 0.0038 | 0.000119 | 142 | 3 | 49 | leaky_relu | PLE |
# | 11 | 0.8308 | 32 | 0.000714 | 0.0706 | 1.11e-05 | 146 | 4 | 49 | leaky_relu | PLE |
# | 12 | **0.8442** | 16 | 0.000856 | 0.3265 | 1.05e-05 | 150 | 3 | 50 | leaky_relu | PLE |
# | 13 | **0.8464** ⭐ | 16 | 0.001988 | 0.3317 | 0.009956 | 141 | 2 | 41 | leaky_relu | PLE |
# | 14 | 0.8317 | 16 | 0.001996 | 0.3600 | 0.009729 | 132 | 3 | 41 | leaky_relu | PLE |
# | 15 | 0.8425 | 16 | 0.001886 | 0.3388 | 0.006497 | 123 | 2 | 42 | leaky_relu | PLE |
# | 16 | 0.8086 | 16 | 0.001762 | 0.3862 | 0.000220 | 156 | 3 | 42 | leaky_relu | PLE |
# | 17 | 0.7999 | 16 | 0.003799 | 0.2152 | 0.001003 | 118 | 2 | 40 | leaky_relu | PLE |
# | 18 | 0.8204 | 16 | 0.000592 | 0.3094 | 0.000273 | 37 | 3 | 45 | leaky_relu | Periodic |
# | 19 | 0.8386 | 16 | 0.001117 | 0.4398 | 0.003744 | 91 | 2 | 36 | leaky_relu | PLE |
# | 20 | 0.8301 | 16 | 0.004749 | 0.1845 | 0.001179 | 200 | 4 | 46 | leaky_relu | PLE |
# | 21 | 0.8283 | 16 | 0.001492 | 0.3583 | 0.008533 | 127 | 2 | 44 | leaky_relu | PLE |
# | 22 | 0.8237 | 16 | 0.002477 | 0.3158 | 0.004870 | 112 | 2 | 37 | leaky_relu | PLE |
# | 23 | 0.8213 | 16 | 0.001219 | 0.3426 | 0.006043 | 145 | 3 | 31 | leaky_relu | PLE |
# | 24 | 0.8247 | 128 | 0.000542 | 0.2745 | 0.000502 | 159 | 3 | 46 | leaky_relu | PLE |
# | 25 | 0.8344 | 16 | 0.002581 | 0.3886 | 0.001766 | 129 | 2 | 39 | leaky_relu | PLE |
# | 26 | 0.8137 | 16 | 0.000100 | 0.3299 | 0.005090 | 57 | 2 | 50 | leaky_relu | Periodic |
# | 27 | 0.8060 | 16 | 0.005404 | 0.4323 | 0.000162 | 17 | 1 | 4 | leaky_relu | PLE |
# | 28 | 0.8309 | 16 | 0.000884 | 0.2729 | 0.002539 | 100 | 3 | 44 | leaky_relu | PLE |
# | 29 | 0.8178 | 128 | 0.001301 | 0.1461 | 0.009278 | 174 | 3 | 34 | leaky_relu | PLE |
# | 30 | 0.8115 | 32 | 0.002718 | 0.2377 | 1.69e-05 | 120 | 4 | 38 | tanh | PLE |
# | 31 | 0.8354 | 64 | 0.000384 | 0.2858 | 3.81e-05 | 162 | 1 | 50 | relu | PLE |
# | 32 | 0.8156 | 64 | 0.000389 | 0.2899 | 1.81e-05 | 163 | 1 | 46 | relu | PLE |
# | 33 | 0.8316 | 64 | 0.000476 | 0.3640 | 1.15e-05 | 138 | 2 | 42 | relu | PLE |
# | 34 | 0.8261 | 64 | 0.001777 | 0.3272 | 5.17e-05 | 152 | 1 | 48 | relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `5` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 64,
#     'learning_rate': 0.005285426279175433,
#     'dropout_rate': 0.46594630836578194,
#     'l2_reg': 4.047725053283987e-05,
#     'ff_dim': 123,
#     'num_layers': 2,
#     'num_heads': 12,
#     'activation': 'tanh',
#     'embed_numerical': 'Periodic'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method | Status |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|--------|
# | 0 | 0.7973 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE | ✓ |
# | 1 | 0.7880 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE | ✓ |
# | 2 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 3 | 0.7870 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic | ✓ |
# | 4 | 0.8123 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE | ✓ |
# | 5 | 0.8238 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE | ✓ |
# | 6 | 0.8053 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic | ✓ |
# | 7 | 0.7940 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE | ✓ |
# | 8 | 0.7915 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic | ✓ |
# | 9 | 0.8198 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic | ✓ |
# | 10 | 0.8158 | 32 | 0.001019 | 0.3540 | 0.000591 | 20 | 3 | 2 | leaky_relu | PLE | ✓ |
# | 11 | 0.8232 | 16 | 0.001295 | 0.4831 | 0.000136 | 115 | 2 | 14 | tanh | Periodic | ✓ |
# | 12 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 13 | 0.7840 | 16 | 0.002005 | 0.4958 | 0.000167 | 67 | 2 | 15 | leaky_relu | Periodic | ✓ |
# | 14 | 0.8267 | 128 | 0.000599 | 0.4040 | 0.000947 | 132 | 3 | 9 | tanh | PLE | ✓ |
# | 15 | 0.7682 | 128 | 0.000108 | 0.3845 | 0.000990 | 139 | 3 | 8 | tanh | PLE | ✓ |
# | 16 | 0.7716 | 128 | 0.000554 | 0.0108 | 0.002277 | 76 | 4 | 19 | leaky_relu | PLE | ✓ |
# | 17 | 0.8066 | 32 | 0.000572 | 0.3386 | 0.000979 | 50 | 3 | 6 | tanh | PLE | ✓ |
# | 18 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 19 | 0.7918 | 128 | 0.000162 | 0.1862 | 0.000271 | 91 | 4 | 20 | tanh | PLE | ✓ |
# | 20 | 0.8025 | 32 | 0.002130 | 0.3224 | 0.001020 | 111 | 3 | 10 | leaky_relu | PLE | ✓ |
# | 21 | 0.8078 | 16 | 0.002340 | 0.4485 | 0.000114 | 128 | 2 | 11 | tanh | Periodic | ✓ |
# | 22 | 0.8081 | 16 | 0.001317 | 0.4317 | 0.000313 | 120 | 2 | 3 | tanh | Periodic | ✓ |
# | 23 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 24 | 0.7953 | 32 | 0.003708 | 0.3796 | 0.000175 | 91 | 2 | 13 | tanh | PLE | ✓ |
# | 25 | 0.8055 | 128 | 0.001514 | 0.3645 | 0.000534 | 111 | 3 | 19 | tanh | PLE | ✓ |
# | 26 | 0.7971 | 32 | 0.000801 | 0.4544 | 0.001473 | 57 | 1 | 27 | tanh | Periodic | ✓ |
# | 27 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 28 | 0.7337 | 128 | 0.000107 | 0.4989 | 0.003748 | 100 | 3 | 10 | leaky_relu | Periodic | ✓ |
# | 29 | — | — | — | — | — | — | — | — | — | — | Pruned |
# | 30 | 0.8023 | 16 | 0.000172 | 0.4047 | 0.001461 | 121 | 3 | 17 | tanh | PLE | ✓ |
# | 31 | 0.8231 | 64 | 0.007838 | 0.4705 | 4.71e-05 | 108 | 2 | 15 | tanh | Periodic | ✓ |
# | 32 | **0.8267** ⭐ | 64 | 0.005285 | 0.4659 | 4.05e-05 | 123 | 2 | 12 | tanh | Periodic | ✓ Best |
# | 33 | 0.8233 | 64 | 0.003238 | 0.4297 | 1.71e-05 | 124 | 2 | 11 | tanh | Periodic | ✓ |
# | 34 | — | — | — | — | — | — | — | — | — | — | Pruned |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `4` (Baseline + Symmetric Cross-Attention + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 16,
#     'learning_rate': 0.006393277610030755,
#     'dropout_rate': 0.3565391348813297,
#     'l2_reg': 0.0003510299681926548,
#     'ff_dim': 156,
#     'num_layers': 2,
#     'num_heads': 30,
#     'activation': 'leaky_relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.7963 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.7652 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | 0.7820 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7585 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | 0.7562 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.7255 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.7261 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7482 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7543 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.7413 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | **0.8133** | 32 | 0.000949 | 0.0038 | 1.13e-05 | 144 | 4 | 44 | leaky_relu | PLE |
# | 11 | 0.8116 | 32 | 0.001123 | 0.0046 | 1.18e-05 | 145 | 4 | 45 | leaky_relu | PLE |
# | 12 | 0.7960 | 32 | 0.001087 | 0.0220 | 1.09e-05 | 139 | 4 | 48 | leaky_relu | PLE |
# | 13 | 0.7926 | 32 | 0.001068 | 0.0008 | 0.009956 | 137 | 3 | 41 | leaky_relu | PLE |
# | 14 | 0.7900 | 16 | 0.002176 | 0.0949 | 0.000121 | 139 | 3 | 42 | leaky_relu | PLE |
# | 15 | 0.7945 | 128 | 0.002106 | 0.1636 | 0.000208 | 152 | 4 | 42 | leaky_relu | PLE |
# | 16 | 0.7994 | 32 | 0.000598 | 0.0806 | 1.03e-05 | 120 | 5 | 45 | leaky_relu | PLE |
# | 17 | 0.8070 | 32 | 0.000745 | 0.0404 | 4.46e-05 | 121 | 3 | 38 | leaky_relu | PLE |
# | 18 | 0.7794 | 32 | 0.002166 | 0.1432 | 0.000148 | 37 | 4 | 50 | leaky_relu | Periodic |
# | 19 | 0.8112 | 16 | 0.004459 | 0.3367 | 0.000428 | 157 | 2 | 30 | leaky_relu | PLE |
# | 20 | 0.7965 | 128 | 0.001440 | 0.0544 | 1.83e-05 | 200 | 5 | 37 | leaky_relu | PLE |
# | 21 | **0.8420** ⭐ | 16 | 0.006393 | 0.3565 | 0.000351 | 156 | 2 | 30 | leaky_relu | PLE |
# | 22 | 0.8152 | 16 | 0.000606 | 0.3554 | 0.001005 | 126 | 2 | 45 | leaky_relu | PLE |
# | 23 | 0.8144 | 16 | 0.000579 | 0.3632 | 0.000934 | 125 | 2 | 19 | leaky_relu | PLE |
# | 24 | 0.7994 | 16 | 0.000542 | 0.3613 | 0.001000 | 120 | 2 | 18 | leaky_relu | PLE |
# | 25 | 0.7285 | 16 | 0.000104 | 0.4000 | 0.001624 | 97 | 2 | 6 | leaky_relu | PLE |
# | 26 | 0.7510 | 16 | 0.000452 | 0.3502 | 0.005055 | 79 | 3 | 13 | leaky_relu | Periodic |
# | 27 | 0.8021 | 16 | 0.004580 | 0.3123 | 0.000669 | 129 | 2 | 20 | leaky_relu | PLE |
# | 28 | 0.8158 | 16 | 0.000759 | 0.4458 | 0.001281 | 58 | 2 | 11 | leaky_relu | PLE |
# | 29 | 0.8197 | 16 | 0.001592 | 0.4403 | 0.001442 | 52 | 3 | 2 | leaky_relu | PLE |
# | 30 | 0.7842 | 16 | 0.003162 | 0.4371 | 0.004122 | 17 | 3 | 2 | tanh | PLE |
# | 31 | 0.8113 | 16 | 0.005883 | 0.4452 | 0.001190 | 47 | 2 | 10 | leaky_relu | PLE |
# | 32 | 0.7962 | 16 | 0.001454 | 0.3949 | 0.000512 | 62 | 3 | 2 | leaky_relu | PLE |
# | 33 | 0.8142 | 16 | 0.000767 | 0.4580 | 0.000230 | 58 | 2 | 11 | leaky_relu | PLE |
# | 34 | 0.8407 | 16 | 0.001678 | 0.3962 | 0.001603 | 88 | 1 | 24 | leaky_relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `3` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN))
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 64,
#     'learning_rate': 0.0012755680432249667,
#     'dropout_rate': 0.11792747175814695,
#     'l2_reg': 0.0005915217137821515,
#     'ff_dim': 59,
#     'num_layers': 4,
#     'num_heads': 4,
#     'activation': 'relu',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.8192 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | **0.8213** | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | 0.8205 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7824 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | **0.8303** | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.8177 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.8070 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7700 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.8043 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.8221 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | 0.8244 | 128 | 0.000884 | 0.0038 | 0.000119 | 142 | 3 | 49 | leaky_relu | PLE |
# | 11 | 0.8273 | 128 | 0.000825 | 0.0086 | 0.000141 | 144 | 3 | 49 | leaky_relu | PLE |
# | 12 | 0.8123 | 128 | 0.000856 | 0.3284 | 0.000116 | 149 | 3 | 50 | leaky_relu | PLE |
# | 13 | 0.8275 | 16 | 0.001927 | 0.1543 | 0.009956 | 142 | 2 | 41 | leaky_relu | PLE |
# | 14 | 0.8163 | 16 | 0.002671 | 0.1740 | 0.009729 | 128 | 2 | 41 | leaky_relu | PLE |
# | 15 | 0.8134 | 16 | 0.002106 | 0.1077 | 1.08e-05 | 160 | 2 | 42 | relu | PLE |
# | 16 | 0.8232 | 16 | 0.001624 | 0.3128 | 0.008688 | 121 | 1 | 42 | leaky_relu | PLE |
# | 17 | 0.8004 | 64 | 0.000107 | 0.2152 | 0.000801 | 161 | 2 | 40 | relu | PLE |
# | 18 | 0.8134 | 16 | 0.000462 | 0.3649 | 0.000273 | 127 | 1 | 45 | leaky_relu | Periodic |
# | 19 | **0.8323** | 64 | 0.004459 | 0.0632 | 0.003744 | 26 | 3 | 36 | relu | PLE |
# | 20 | 0.8285 | 64 | 0.005071 | 0.0667 | 0.003370 | 18 | 4 | 36 | relu | PLE |
# | 21 | 0.8181 | 64 | 0.003896 | 0.0623 | 0.003334 | 16 | 4 | 35 | relu | PLE |
# | 22 | 0.8133 | 64 | 0.005412 | 0.0561 | 0.001282 | 43 | 4 | 29 | relu | PLE |
# | 23 | 0.8153 | 64 | 0.006013 | 0.1108 | 0.004269 | 17 | 3 | 37 | relu | PLE |
# | 24 | 0.8077 | 64 | 0.000542 | 0.2856 | 0.001261 | 50 | 5 | 46 | relu | PLE |
# | 25 | 0.8038 | 64 | 0.005613 | 0.1937 | 0.004751 | 71 | 4 | 21 | relu | PLE |
# | 26 | 0.7941 | 64 | 0.001390 | 0.2576 | 0.000338 | 33 | 3 | 31 | relu | Periodic |
# | 27 | **0.8357** ⭐ | 64 | 0.001276 | 0.1179 | 0.000592 | 59 | 4 | 4 | relu | PLE |
# | 28 | 0.8186 | 64 | 0.001197 | 0.1043 | 0.000230 | 58 | 5 | 4 | relu | PLE |
# | 29 | 0.8168 | 32 | 0.000546 | 0.0265 | 0.000607 | 92 | 4 | 11 | relu | PLE |
# | 30 | 0.8297 | 64 | 0.000350 | 0.1303 | 2.89e-05 | 57 | 4 | 12 | relu | PLE |
# | 31 | 0.8196 | 64 | 0.000289 | 0.1361 | 2.37e-05 | 62 | 4 | 4 | relu | PLE |
# | 32 | 0.7943 | 64 | 0.000375 | 0.0952 | 4.30e-05 | 85 | 4 | 9 | relu | PLE |
# | 33 | 0.7600 | 64 | 0.000343 | 0.1799 | 1.71e-05 | 33 | 5 | 2 | relu | PLE |
# | 34 | 0.8070 | 64 | 0.000229 | 0.0494 | 5.38e-05 | 46 | 3 | 13 | relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 32,
#     'learning_rate': 0.0059030125874360165,
#     'dropout_rate': 0.10530297634027552,
#     'l2_reg': 0.0020410048624941615,
#     'ff_dim': 76,
#     'num_layers': 3,
#     'num_heads': 42,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.7903 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.7894 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | 0.8224 | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7483 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | 0.8128 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.7958 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | **0.8320** | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7367 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7596 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.7745 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | 0.7510 | 128 | 0.002510 | 0.0038 | 0.000198 | 134 | 3 | 2 | leaky_relu | Periodic |
# | 11 | 0.7868 | 128 | 0.009562 | 0.3566 | 0.000173 | 25 | 4 | 2 | tanh | Periodic |
# | 12 | 0.7741 | 128 | 0.003099 | 0.3648 | 0.000383 | 31 | 3 | 17 | tanh | Periodic |
# | 13 | 0.8280 | 16 | 0.003951 | 0.1905 | 0.009956 | 64 | 4 | 8 | leaky_relu | PLE |
# | 14 | **0.8417** | 16 | 0.001858 | 0.1803 | 0.009729 | 77 | 2 | 11 | leaky_relu | PLE |
# | 15 | 0.7597 | 16 | 0.001307 | 0.1250 | 0.006497 | 105 | 2 | 10 | leaky_relu | Periodic |
# | 16 | 0.7709 | 16 | 0.000920 | 0.2424 | 0.001047 | 132 | 2 | 9 | leaky_relu | Periodic |
# | 17 | 0.8307 | 64 | 0.001318 | 0.1669 | 0.003561 | 88 | 1 | 41 | leaky_relu | PLE |
# | 18 | 0.8349 | 16 | 0.000764 | 0.0708 | 0.000712 | 53 | 2 | 12 | leaky_relu | PLE |
# | 19 | 0.8041 | 16 | 0.000721 | 0.0574 | 0.001251 | 50 | 3 | 13 | leaky_relu | PLE |
# | 20 | 0.8049 | 16 | 0.000593 | 0.0939 | 0.006485 | 51 | 2 | 19 | leaky_relu | PLE |
# | 21 | 0.8318 | 16 | 0.002322 | 0.0218 | 0.000466 | 91 | 1 | 6 | leaky_relu | PLE |
# | 22 | 0.8202 | 16 | 0.001679 | 0.2797 | 0.000234 | 51 | 2 | 12 | leaky_relu | PLE |
# | 23 | 0.7686 | 64 | 0.004370 | 0.2213 | 9.36e-05 | 126 | 2 | 6 | leaky_relu | Periodic |
# | 24 | 0.8261 | 16 | 0.005105 | 0.1128 | 0.001435 | 87 | 3 | 19 | tanh | PLE |
# | 25 | 0.7523 | 16 | 0.000104 | 0.1799 | 0.000664 | 66 | 1 | 5 | leaky_relu | PLE |
# | 26 | 0.7606 | 64 | 0.001927 | 0.0462 | 0.000111 | 119 | 2 | 12 | tanh | Periodic |
# | 27 | 0.8228 | 32 | 0.000570 | 0.1416 | 0.000329 | 16 | 1 | 20 | leaky_relu | PLE |
# | 28 | 0.7771 | 16 | 0.001176 | 0.3310 | 0.004082 | 147 | 3 | 14 | leaky_relu | Periodic |
# | 29 | 0.8368 | 32 | 0.006217 | 0.0926 | 0.001833 | 97 | 2 | 39 | tanh | PLE |
# | 30 | **0.8525** | 32 | 0.006073 | 0.0798 | 0.009588 | 44 | 3 | 39 | tanh | PLE |
# | 31 | 0.8336 | 32 | 0.007023 | 0.0876 | 0.006179 | 43 | 3 | 42 | tanh | PLE |
# | 32 | 0.8435 | 32 | 0.005943 | 0.0602 | 0.009529 | 76 | 2 | 39 | tanh | PLE |
# | 33 | **0.8573** ⭐ | 32 | 0.005903 | 0.1053 | 0.002041 | 76 | 3 | 42 | tanh | PLE |
# | 34 | 0.7707 | 32 | 0.006102 | 0.0355 | 0.009448 | 76 | 4 | 49 | tanh | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 16,
#     'learning_rate': 0.005674018095876286,
#     'dropout_rate': 0.357649350688716,
#     'l2_reg': 0.00018082955891304315,
#     'ff_dim': 87,
#     'num_layers': 2,
#     'num_heads': 38,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Trials Table:
# | Trial | Value | Batch Size | Learning Rate | Dropout Rate | L2 Reg | FF Dim | Layers | Heads | Activation | Embed Method |
# |-------|-------|------------|---------------|--------------|--------|--------|--------|-------|------------|--------------|
# | 0 | 0.7300 | 32 | 0.000205 | 0.0780 | 1.49e-05 | 176 | 4 | 36 | tanh | PLE |
# | 1 | 0.7438 | 64 | 0.000382 | 0.3059 | 2.62e-05 | 70 | 2 | 24 | relu | PLE |
# | 2 | **0.7895** | 128 | 0.008536 | 0.4042 | 8.20e-05 | 34 | 4 | 23 | tanh | PLE |
# | 3 | 0.7620 | 16 | 0.000234 | 0.4848 | 0.002115 | 189 | 5 | 31 | relu | Periodic |
# | 4 | 0.7175 | 64 | 0.000365 | 0.2713 | 2.65e-05 | 164 | 1 | 50 | relu | PLE |
# | 5 | 0.7640 | 32 | 0.000171 | 0.4316 | 0.000741 | 77 | 1 | 17 | tanh | PLE |
# | 6 | 0.7510 | 64 | 0.003483 | 0.2469 | 0.000370 | 95 | 1 | 7 | tanh | Periodic |
# | 7 | 0.7231 | 64 | 0.000143 | 0.1449 | 3.05e-05 | 187 | 5 | 33 | relu | PLE |
# | 8 | 0.7387 | 32 | 0.000286 | 0.2136 | 0.002845 | 175 | 1 | 27 | relu | Periodic |
# | 9 | 0.7559 | 64 | 0.008781 | 0.4812 | 5.69e-05 | 107 | 2 | 15 | tanh | Periodic |
# | 10 | 0.7438 | 128 | 0.001311 | 0.3489 | 0.000110 | 18 | 4 | 2 | leaky_relu | PLE |
# | 11 | 0.7470 | 128 | 0.001380 | 0.3879 | 0.000397 | 35 | 3 | 17 | tanh | PLE |
# | 12 | **0.8246** | 32 | 0.007906 | 0.4082 | 0.001171 | 60 | 3 | 17 | tanh | PLE |
# | 13 | 0.8104 | 128 | 0.009519 | 0.4055 | 0.009956 | 51 | 3 | 44 | leaky_relu | PLE |
# | 14 | **0.8360** | 16 | 0.003506 | 0.3118 | 0.009729 | 59 | 3 | 43 | leaky_relu | PLE |
# | 15 | 0.8288 | 16 | 0.003743 | 0.3234 | 0.006497 | 134 | 2 | 42 | leaky_relu | PLE |
# | 16 | 0.8190 | 16 | 0.002922 | 0.0099 | 0.009119 | 138 | 2 | 39 | leaky_relu | PLE |
# | 17 | 0.8107 | 16 | 0.003881 | 0.1642 | 0.004835 | 131 | 2 | 44 | leaky_relu | PLE |
# | 18 | 0.7478 | 16 | 0.000730 | 0.3096 | 0.004289 | 135 | 3 | 50 | leaky_relu | Periodic |
# | 19 | 0.7584 | 16 | 0.001942 | 0.3367 | 0.001220 | 91 | 2 | 41 | leaky_relu | PLE |
# | 20 | 0.7373 | 16 | 0.000642 | 0.2044 | 0.005046 | 123 | 4 | 45 | leaky_relu | PLE |
# | 21 | 0.7757 | 32 | 0.005253 | 0.3573 | 0.001365 | 65 | 3 | 11 | leaky_relu | PLE |
# | 22 | 0.8002 | 16 | 0.005339 | 0.2847 | 0.000739 | 154 | 3 | 30 | leaky_relu | PLE |
# | 23 | 0.7958 | 32 | 0.002027 | 0.4482 | 0.002664 | 53 | 3 | 20 | leaky_relu | PLE |
# | 24 | **0.8403** ⭐ | 16 | 0.005674 | 0.3576 | 0.000181 | 87 | 2 | 38 | tanh | PLE |
# | 25 | 0.8027 | 16 | 0.002404 | 0.2398 | 0.000153 | 86 | 2 | 36 | leaky_relu | PLE |
# | 26 | 0.7282 | 16 | 0.005020 | 0.3611 | 0.000202 | 113 | 2 | 40 | tanh | Periodic |
# | 27 | 0.8318 | 16 | 0.004384 | 0.3177 | 0.000669 | 108 | 2 | 47 | leaky_relu | PLE |
# | 28 | 0.8316 | 16 | 0.006157 | 0.2821 | 0.000252 | 107 | 1 | 47 | leaky_relu | PLE |
# | 29 | 0.8167 | 16 | 0.001716 | 0.0938 | 6.26e-05 | 78 | 3 | 37 | tanh | PLE |
# | 30 | 0.8271 | 16 | 0.002718 | 0.2035 | 0.000175 | 40 | 4 | 34 | tanh | PLE |
# | 31 | 0.8276 | 16 | 0.006023 | 0.2741 | 0.000601 | 108 | 1 | 47 | leaky_relu | PLE |
# | 32 | 0.8088 | 16 | 0.006506 | 0.2903 | 0.000262 | 102 | 1 | 47 | leaky_relu | PLE |
# | 33 | 0.8155 | 16 | 0.003845 | 0.3716 | 1.40e-05 | 116 | 1 | 48 | leaky_relu | PLE |
# | 34 | 0.8268 | 16 | 0.007057 | 0.3158 | 0.000111 | 76 | 2 | 43 | leaky_relu | PLE |

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `0` (Baseline)
#
# Tag: `_baseline`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 32,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8679
# loss: 0.3890
# precision: 0.6058
# recall: 0.5940
# roc_auc: 0.8495
# ```
