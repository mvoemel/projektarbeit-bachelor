# %% [markdown]
# # Log Book
#
# Containing configs and results of train and tune runs.

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `8` (Baseline + Symmetric Cross-Attention + Transformer Block + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_adam`
#
# Optimizer: `ADAM`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `_sgd`
#
# Optimizer: `SGD`
#
# Trials: `35`
#
# Best Trial: `TBA` with AOC `TBA`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `0` (Baseline)
#
# Tag: `_baseline`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 32,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# TBA
# ```
