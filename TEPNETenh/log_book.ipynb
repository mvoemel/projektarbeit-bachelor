# %% [markdown]
# # Log Book
#
# Containing configs and results of train and tune runs.

# %%
Run: 4

---- Version 3 (TRAIN) ----
Parameters:
HP_BATCH_SIZE = 64
HP_EPOCHS = 75
HP_LEARNING_RATE = 0.0059
HP_DROPOUT = 0.2414
HP_L2_REG = 0.0082
HP_FF_DIM = 135
HP_NUM_LAYERS = 1
HP_NUM_HEADS = 50
HP_ACTIVATION = "tanh"
HP_EMBED_NUMERICAL = "PLE"

Test Results:
TBA

# %%
Run: 3

---- Version 2 (TRAIN) ----
Parameters:
HP_BATCH_SIZE = 64
HP_EPOCHS = 75
HP_LEARNING_RATE = 0.0059
HP_DROPOUT = 0.2414
HP_L2_REG = 0.0082
HP_FF_DIM = 135
HP_NUM_LAYERS = 1
HP_NUM_HEADS = 50
HP_ACTIVATION = "tanh"
HP_EMBED_NUMERICAL = "PLE"

Test Results:
accuracy: 0.8088
loss: 0.5298
precision: 0.4224
recall: 0.4011
roc_auc: 0.7492

# %%
Run: 2

---- Version 1 (TRAIN) ----
Parameters:
HP_BATCH_SIZE = 64
HP_EPOCHS = 75
HP_LEARNING_RATE = 0.0059
HP_DROPOUT = 0.2414
HP_L2_REG = 0.0082
HP_FF_DIM = 135
HP_NUM_LAYERS = 1
HP_NUM_HEADS = 50
HP_ACTIVATION = "tanh"
HP_EMBED_NUMERICAL = "PLE"

Test Results:
accuracy: 0.8938
loss: 0.3474
precision: 0.8597
recall: 0.4337
roc_auc: 0.8338

# %%
Run: 1

---- Version 0 (TRAIN) ----
Parameters:
HP_BATCH_SIZE = 64
HP_EPOCHS = 75
HP_LEARNING_RATE = 0.0059
HP_DROPOUT = 0.2414
HP_L2_REG = 0.0082
HP_FF_DIM = 135
HP_NUM_LAYERS = 1
HP_NUM_HEADS = 50
HP_ACTIVATION = "tanh"
HP_EMBED_NUMERICAL = "PLE"

Test Results:
accuracy: 0.8903
loss: 0.3604
precision: 0.8622
recall: 0.4066
roc_auc: 0.8193
