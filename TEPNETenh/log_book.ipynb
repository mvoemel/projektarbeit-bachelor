# %% [markdown]
# # Log Book
#
# Containing configs and results of train and tune runs.

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `2` (Baseline + Symmetric Cross-Attention + Transformer Block)
#
# Trials: `20`
#
# Optimizer: `ADAM`
#
# Best Hparams:
# ```py
# TBA
# ```
#
# Some Logs:
# ```sh
# TBA
# ```

# %% [markdown]
# ---
#
#
# Mode: `TUNE`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Trials: `8`
#
# Optimizer: `SGD`
#
# Best Trial: Trial `2` with value `0.7905476689338684`
#
# Best Hparams:
# ```py
# {
#     'batch_size': 128,
#     'learning_rate': 0.00853618986286683,
#     'dropout_rate': 0.40419867405823057,
#     'l2_reg': 8.200518402245828e-05,
#     'ff_dim': 34,
#     'num_layers': 4,
#     'num_heads': 23,
#     'activation': 'tanh',
#     'embed_numerical': 'PLE'
# }
# ```
#
# Some Logs:
# ```sh
# [I 2025-12-13 01:42:16,428] Trial 0 finished with value: 0.7361832857131958 and parameters: {'batch_size': 32, 'learning_rate': 0.0002051338263087451, 'dropout_rate': 0.07799726016810132, 'l2_reg': 1.493656855461762e-05, 'ff_dim': 176, 'num_layers': 4, 'num_heads': 36, 'activation': 'tanh', 'embed_numerical': 'PLE'}. Best is trial 0 with value: 0.7361832857131958.
# [I 2025-12-13 14:39:30,940] Trial 1 finished with value: 0.777259886264801 and parameters: {'batch_size': 64, 'learning_rate': 0.0003823475224675188, 'dropout_rate': 0.30592644736118974, 'l2_reg': 2.621087878265438e-05, 'ff_dim': 70, 'num_layers': 2, 'num_heads': 24, 'activation': 'relu', 'embed_numerical': 'PLE'}. Best is trial 1 with value: 0.777259886264801.
# [I 2025-12-13 19:46:52,976] Trial 2 finished with value: 0.7905476689338684 and parameters: {'batch_size': 128, 'learning_rate': 0.00853618986286683, 'dropout_rate': 0.40419867405823057, 'l2_reg': 8.200518402245828e-05, 'ff_dim': 34, 'num_layers': 4, 'num_heads': 23, 'activation': 'tanh', 'embed_numerical': 'PLE'}. Best is trial 2 with value: 0.7905476689338684.
# [I 2025-12-13 23:52:53,933] Trial 3 finished with value: 0.74261474609375 and parameters: {'batch_size': 16, 'learning_rate': 0.00023426581058204064, 'dropout_rate': 0.4847923138822793, 'l2_reg': 0.002115429079726122, 'ff_dim': 189, 'num_layers': 5, 'num_heads': 31, 'activation': 'relu', 'embed_numerical': 'Periodic'}. Best is trial 2 with value: 0.7905476689338684.
# [I 2025-12-14 12:59:39,347] Trial 4 finished with value: 0.7829585075378418 and parameters: {'batch_size': 64, 'learning_rate': 0.0003646439558980723, 'dropout_rate': 0.27134804157912423, 'l2_reg': 2.6471141828218167e-05, 'ff_dim': 164, 'num_layers': 1, 'num_heads': 50, 'activation': 'relu', 'embed_numerical': 'PLE'}. Best is trial 2 with value: 0.7905476689338684.
# [I 2025-12-14 20:11:44,243] Trial 5 finished with value: 0.7297539710998535 and parameters: {'batch_size': 32, 'learning_rate': 0.0001705053926026929, 'dropout_rate': 0.43155171293779676, 'l2_reg': 0.0007411299781083245, 'ff_dim': 77, 'num_layers': 1, 'num_heads': 17, 'activation': 'tanh', 'embed_numerical': 'PLE'}. Best is trial 2 with value: 0.7905476689338684.
# [I 2025-12-14 23:29:47,717] Trial 6 finished with value: 0.7393510341644287 and parameters: {'batch_size': 64, 'learning_rate': 0.003482846706526885, 'dropout_rate': 0.24689779818219537, 'l2_reg': 0.0003699972431463808, 'ff_dim': 95, 'num_layers': 1, 'num_heads': 7, 'activation': 'tanh', 'embed_numerical': 'Periodic'}. Best is trial 2 with value: 0.7905476689338684.
# [I 2025-12-15 12:53:43,437] Trial 7 finished with value: 0.7640577554702759 and parameters: {'batch_size': 64, 'learning_rate': 0.00014254757044027455, 'dropout_rate': 0.144875726456884, 'l2_reg': 3.0455368715396772e-05, 'ff_dim': 187, 'num_layers': 5, 'num_heads': 33, 'activation': 'relu', 'embed_numerical': 'PLE'}. Best is trial 2 with value: 0.7905476689338684.
# [W 2025-12-15 13:00:06,027] Trial 8 failed with parameters: {'batch_size': 32, 'learning_rate': 0.000285673742984719, 'dropout_rate': 0.21355389431312816, 'l2_reg': 0.00284475125551182, 'ff_dim': 175, 'num_layers': 1, 'num_heads': 27, 'activation': 'relu', 'embed_numerical': 'Periodic'} because of the following error: KeyboardInterrupt().
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `0` (Baseline)
#
# Tag: `run1`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 32,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8947
# loss: 0.3431
# precision: 0.7920
# recall: 0.4992
# roc_auc: 0.8367
# ```

# %% [markdown]
# ---
#
# Mode: `TRAIN`
#
# Version: `5` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN) + Deep ResNet Classifier Head)
#
# Tag: `old4`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 64,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8766
# loss: 0.4287
# precision: 0.7300
# recall: 0.4121
# roc_auc: 0.7780
# ```

# %% [markdown]
# ---
#
# Mode: `TRAIN`
#
# Version: `3` (Baseline + Symmetric Cross-Attention + Interaction Map (2D CNN))
#
# Tag: `old3`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 64,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8088
# loss: 0.5298
# precision: 0.4224
# recall: 0.4011
# roc_auc: 0.7492
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `1` (Baseline + Symmetric Cross-Attention)
#
# Tag: `old2`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 64,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8938
# loss: 0.3474
# precision: 0.8597
# recall: 0.4337
# roc_auc: 0.8338
# ```

# %% [markdown]
# ---
#
#
# Mode: `TRAIN`
#
# Version: `0` (Baseline)
#
# Tag: `old1`
#
# Optimizer: `SGD`
#
# ```py
# HYPER_PARAMETERS = {
#     "batch_size": 64,
#     "learning_rate": 0.0059,
#     "dropout_rate": 0.2414,
#     "l2_reg": 0.0082,
#     "ff_dim": 135,
#     "num_layers": 1,
#     "num_heads": 50,
#     "activation": "tanh",
#     "embed_numerical": "PLE"
# }
# ```
#
# Test Results:
# ```sh
# accuracy: 0.8903
# loss: 0.3604
# precision: 0.8622
# recall: 0.4066
# roc_auc: 0.8193
# ```
